# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.ma as ma
from astropy.table import Table

# %%
# Read the table
t1 = Table.read('wright_spec.vot',format='votable')

print(t1["BTmag","VTmag"])
# Out:
# WARNING: W27: wright_spec.vot:50:2: W27: COOSYS deprecated in VOTable 1.2 [astropy.io.votable.tree]
# BTmag  VTmag
#  mag    mag
# ------ ------
# 10.488  8.670
# 11.318 10.521
#  9.510  9.387
#  9.713  8.907
# 10.024  9.550
# 10.565  9.468
#  9.443  8.756
# 11.920 10.072
# 10.117  9.032
# 11.512  9.749
#    ...    ...
#  9.294  8.762
# 11.092  9.840
# 10.953 10.261
# 10.286  9.767
# 10.878 10.337
#  9.378  8.952
# 10.885 10.565
# 11.509 10.200
#  6.899  6.585
# 10.990 10.470
# Length = 351863 rows

# %%
print(t1.colnames)
# Out:
# ['TYC1', 'TYC2', 'TYC3', 'RAJ2000', 'DEJ2000', 'VTmag', 'BTmag', 'r_SpType', 'Dist', 'Mag', 'Teff', 'SpType']

# %%
Teff = t1["Teff"]
plt.title("Histogram of Teff")
plt.xlabel('Teff bins')
plt.ylabel('Number of stars in bin')
plt.hist(Teff,bins=30,color='b')
plt.show()

plt.title("Histogram of Teff")
plt.xlabel('Teff bins')
plt.ylabel('Number of stars in bin')
plt.hist(Teff,bins=45,range=(2000,12000),color='b')
plt.show()

print("Results of number of stars in low Teff bins for Wright et al Catalog")
TeffMask = ma.masked_outside(Teff,2000,2500)
print("   Number of stars between 2000 and 2500: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,2501,3000)
print("   Number of stars between 2501 and 3000: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,3001,3500)
print("   Number of stars between 3001 and 3500: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,3501,4000)
print("   Number of stars between 3500 and 4000: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,4001,4500)
print("   Number of stars between 4001 and 4500: ", TeffMask.count())
# Out:
# Results of number of stars in low Teff bins for Wright et al Catalog
#    Number of stars between 2000 and 2500:  0
#    Number of stars between 2501 and 3000:  1564
#    Number of stars between 3001 and 3500:  1951
#    Number of stars between 3500 and 4000:  23388
#    Number of stars between 4001 and 4500:  24925

# %%
Teff = t1["Teff"]
Bmags = t1["BTmag"]
Vmags = t1["VTmag"]
BmV = Bmags - Vmags
plt.title("B-V mag versus Teff")
plt.xlabel('B-V magnitude')
plt.ylabel('Teff')
plt.scatter(BmV,Teff,color='b',s=1.0)
plt.show()

plt.title("B-V mag versus Teff")
plt.xlabel('B-V magnitude')
plt.ylabel('Teff')
plt.ylim(2500,12000)
plt.scatter(BmV,Teff,color='b',s=1.0)
plt.show()

TeffMask = ma.masked_outside(Teff,3500,4000)
BmVMask = ma.array(BmV,mask=TeffMask.mask)
BmVplt = BmVMask.compressed()
plt.title("Histogram of B-V for Teff of 3,500-4,000")
plt.xlabel('B-V bins')
plt.ylabel('Number of stars in bin')
plt.hist(BmVplt,bins=35,range=(-0.5,3.5),color='b')
plt.show()
print("Number of stars in Teff=3,500-4,000:", TeffMask.count())
print("     Median value: ", np.mean(BmVplt))
print("     Variance:     ",np.std(BmVplt))

TeffMask = ma.masked_outside(Teff,8000,8500)
BmVMask = ma.array(BmV,mask=TeffMask.mask)
BmVplt = BmVMask.compressed()
plt.title("Histogram of B-V for Teff of 8,000-8,500")
plt.xlabel('B-V bins')
plt.ylabel('Number of stars in bin')
plt.hist(BmVplt,bins=35,range=(-0.5,3.5),color='b')
plt.show()
print("Number of stars in Teff=8,000-8,500:", TeffMask.count())
print("     Median value: ", np.mean(BmVplt))
print("     Variance:     ",np.std(BmVplt))

temps = [2500,3000,3500,4000,4500,5000,5500,6000,6500,7000,7500,8000,8500,9000,9500,10000,10500,11000,11500,12000]
print(temps)
Tave = []
BmVave = []
BmVstd = []
for tlow in temps:
    thi = tlow + 499.
    tmean = (thi+tlow)/2.0
    TeffMask = ma.masked_outside(Teff,tlow,thi)
    BmVMask = ma.array(BmV,mask=TeffMask.mask)
    BmVplt = BmVMask.compressed()
    Tave.append(tmean)
    BmVave.append(np.mean(BmVplt))
    BmVstd.append(np.std(BmVplt))
    print("Number of stars in Teff= %g - %g :"%(tlow,thi), TeffMask.count())
    print("     Median value: ", np.mean(BmVplt))
    print("     Variance:     ",np.std(BmVplt))
print(Tave)
print(BmVave)

plt.title("B-V Color versus Teff of Wright et al Catalog")
plt.xlabel('Effective Temperature')
plt.ylabel('B-V color (mags)')
pllab1 = plt.scatter(Tave,BmVave,s=20,c='b', label='plt1')
pllab2 = plt.scatter(Tave,BmVstd,s=20,c='r', label='plt2')
plt.legend([pllab1,pllab2],['B-V Color','Std in B-V'])
plt.show()
# Out:
# Number of stars in Teff=3,500-4,000: 23388
#      Median value:  1.78048
#      Variance:      0.32127
# Number of stars in Teff=8,000-8,500: 10683
#      Median value:  0.29616
#      Variance:      0.187928
# [2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000]
# Number of stars in Teff= 2500 - 2999 : 1564
#      Median value:  1.86456
#      Variance:      0.760371
# Number of stars in Teff= 3000 - 3499 : 1951
#      Median value:  1.82262
#      Variance:      0.290516
# Number of stars in Teff= 3500 - 3999 : 21550
#      Median value:  1.77499
#      Variance:      0.33061
# Number of stars in Teff= 4000 - 4499 : 26763
#      Median value:  1.58053
#      Variance:      0.267531
# Number of stars in Teff= 4500 - 4999 : 68476
#      Median value:  1.2705
#      Variance:      0.221048
# Number of stars in Teff= 5000 - 5499 : 25132
#      Median value:  0.984895
#      Variance:      0.281307
# Number of stars in Teff= 5500 - 5999 : 11361
#      Median value:  0.784256
#      Variance:      0.16976
# Number of stars in Teff= 6000 - 6499 : 67827
#      Median value:  0.595971
#      Variance:      0.165347
# Number of stars in Teff= 6500 - 6999 : 19646
#      Median value:  0.470084
#      Variance:      0.114424
# Number of stars in Teff= 7000 - 7499 : 14885
#      Median value:  0.409385
#      Variance:      0.133061
# Number of stars in Teff= 7500 - 7999 : 6638
#      Median value:  0.350054
#      Variance:      0.12253
# Number of stars in Teff= 8000 - 8499 : 10683
#      Median value:  0.29616
#      Variance:      0.187928
# Number of stars in Teff= 8500 - 8999 : 18526
#      Median value:  0.260154
#      Variance:      0.164257
# Number of stars in Teff= 9000 - 9499 : 8064
#      Median value:  0.212583
#      Variance:      0.160081
# Number of stars in Teff= 9500 - 9999 : 18131
#      Median value:  0.152628
#      Variance:      0.177818
# Number of stars in Teff= 10000 - 10499 : 2495
#      Median value:  0.171653
#      Variance:      0.167736
# Number of stars in Teff= 10500 - 10999 : 6560
#      Median value:  0.0728865
#      Variance:      0.146351
# Number of stars in Teff= 11000 - 11499 : 4471
#      Median value:  0.0965549
#      Variance:      0.163918
# Number of stars in Teff= 11500 - 11999 : 3885
#      Median value:  0.104886
#      Variance:      0.201949
# Number of stars in Teff= 12000 - 12499 : 2829
#      Median value:  0.0642379
#      Variance:      0.165951
# [2749.5, 3249.5, 3749.5, 4249.5, 4749.5, 5249.5, 5749.5, 6249.5, 6749.5, 7249.5, 7749.5, 8249.5, 8749.5, 9249.5, 9749.5, 10249.5, 10749.5, 11249.5, 11749.5, 12249.5]
# [1.8645582, 1.8226177, 1.7749928, 1.5805329, 1.2704958, 0.98489493, 0.78425634, 0.59597099, 0.4700844, 0.40938517, 0.35005409, 0.29616019, 0.26015383, 0.21258308, 0.15262826, 0.17165263, 0.072886549, 0.096554913, 0.10488591, 0.0642379]

# %%
# Read the table
t2 = Table.read('tgas125xwright.vot',format='votable')
# Out:
# WARNING: W03: tgas125xwright.vot:25:0: W03: Implicitly generating an ID from a name '<FG>' -> '__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: tgas125xwright.vot:25:0: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: tgas125xwright.vot:26:0: W03: Implicitly generating an ID from a name 'e_<FG>' -> 'e__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: tgas125xwright.vot:26:0: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: tgas125xwright.vot:27:0: W03: Implicitly generating an ID from a name '<Gmag>' -> '__Gmag_' [astropy.io.votable.xmlutil]
# WARNING: W32: tgas125xwright.vot:31:0: W32: Duplicate ID 'TYC2' renamed to 'TYC2_2' to ensure uniqueness [astropy.io.votable.tree]
# WARNING: W33: tgas125xwright.vot:31:0: W33: Column name 'TYC2' renamed to 'TYC2 2' to ensure uniqueness [astropy.io.votable.tree]
# WARNING: W49: tgas125xwright.vot:44:60: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:45:60: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:46:60: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:48:61: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:49:58: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:50:60: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:51:61: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:56:61: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:57:61: W49: Empty cell illegal for integer fields. [astropy.io.votable.converters]
# WARNING: W49: tgas125xwright.vot:58:60: W49: Empty cell illegal for integer fields. (suppressing further warnings of this type...) [astropy.io.votable.converters]

# %%
print(t2.colnames)
# Out:
# ['d_arcsec', '_RAJ2000', '_DEJ2000', 'HIP', 'TYC2', 'Source', 'RA_ICRS', 'e_RA_ICRS', 'DE_ICRS', 'e_DE_ICRS', 'Plx', 'e_Plx', 'pmRA', 'e_pmRA', 'pmDE', 'e_pmDE', 'Dup', '__FG_', 'e__FG_', '__Gmag_', 'Var', 'TYC1', 'TYC2_2', 'TYC3', 'RAJ2000', 'DEJ2000', 'VTmag', 'BTmag', 'r_SpType', 'Dist', 'Mag', 'Teff', 'SpType']

# %%
Teff = t2["Teff"]
plt.title("Histogram of Teff")
plt.xlabel('Teff bins')
plt.ylabel('Number of stars in bin')
plt.hist(Teff,bins=30,color='b')
plt.show()

plt.title("Histogram of Teff")
plt.xlabel('Teff bins')
plt.ylabel('Number of stars in bin')
plt.hist(Teff,bins=45,range=(2000,12000),color='b')
plt.show()

print("Results of number of stars in low Teff bins for TGAS x Wright et al Catalog")
TeffMask = ma.masked_outside(Teff,2000,2500)
print("   Number of stars between 2000 and 2500: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,2501,3000)
print("   Number of stars between 2501 and 3000: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,3001,3500)
print("   Number of stars between 3001 and 3500: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,3501,4000)
print("   Number of stars between 3500 and 4000: ", TeffMask.count())
TeffMask = ma.masked_outside(Teff,4001,4500)
print("   Number of stars between 4001 and 4500: ", TeffMask.count())
# Out:
# Results of number of stars in low Teff bins for TGAS x Wright et al Catalog
#    Number of stars between 2000 and 2500:  0
#    Number of stars between 2501 and 3000:  5
#    Number of stars between 3001 and 3500:  5
#    Number of stars between 3500 and 4000:  241
#    Number of stars between 4001 and 4500:  494

# %%
Teff = t2["Teff"]
Bmags = t2["BTmag"]
Vmags = t2["VTmag"]
BmV = Bmags - Vmags
plt.title("B-V mag versus Teff")
plt.xlabel('B-V magnitude')
plt.ylabel('Teff')
plt.scatter(BmV,Teff,color='b',s=1.0)
plt.show()

plt.title("B-V mag versus Teff")
plt.xlabel('B-V magnitude')
plt.ylabel('Teff')
plt.ylim(2500,12000)
plt.scatter(BmV,Teff,color='b',s=1.0)
plt.show()

TeffMask = ma.masked_outside(Teff,3500,4000)
BmVMask = ma.array(BmV,mask=TeffMask.mask)
BmVplt = BmVMask.compressed()
plt.title("Histogram of B-V for Teff of 3,500-4,000")
plt.xlabel('B-V bins')
plt.ylabel('Number of stars in bin')
plt.hist(BmVplt,bins=35,range=(-0.5,3.5),color='b')
plt.show()
print("Number of stars in Teff=3,500-4,000:", TeffMask.count())
print("     Median value: ", np.mean(BmVplt))
print("     Variance:     ",np.std(BmVplt))

TeffMask = ma.masked_outside(Teff,8000,8500)
BmVMask = ma.array(BmV,mask=TeffMask.mask)
BmVplt = BmVMask.compressed()
plt.title("Histogram of B-V for Teff of 8,000-8,500")
plt.xlabel('B-V bins')
plt.ylabel('Number of stars in bin')
plt.hist(BmVplt,bins=35,range=(-0.5,3.5),color='b')
plt.show()
print("Number of stars in Teff=8,000-8,500:", TeffMask.count())
print("     Median value: ", np.mean(BmVplt))
print("     Variance:     ",np.std(BmVplt))

temps = [2500,3000,3500,4000,4500,5000,5500,6000,6500,7000,7500,8000,8500,9000,9500,10000,10500,11000,11500,12000]
print(temps)
Tave = []
BmVave = []
BmVstd = []
for tlow in temps:
    thi = tlow + 499.
    tmean = (thi+tlow)/2.0
    TeffMask = ma.masked_outside(Teff,tlow,thi)
    BmVMask = ma.array(BmV,mask=TeffMask.mask)
    BmVplt = BmVMask.compressed()
    Tave.append(tmean)
    BmVave.append(np.mean(BmVplt))
    BmVstd.append(np.std(BmVplt))
    print("Number of stars in Teff= %g - %g :"%(tlow,thi), TeffMask.count())
    print("     Median value: ", np.mean(BmVplt))
    print("     Variance:     ",np.std(BmVplt))
print(Tave)
print(BmVave)

plt.title("B-V Color versus Teff of Wright et al Catalog")
plt.xlabel('Effective Temperature')
plt.ylabel('B-V color (mags)')
pllab1 = plt.scatter(Tave,BmVave,s=20,c='b', label='plt1')
pllab2 = plt.scatter(Tave,BmVstd,s=20,c='r', label='plt2')
plt.legend([pllab1,pllab2],['B-V Color','Std in B-V'])
plt.errorbar(Tave,BmVave,yerr=BmVstd)
plt.show()
# Out:
# Number of stars in Teff=3,500-4,000: 241
#      Median value:  1.16004
#      Variance:      0.285972
# Number of stars in Teff=8,000-8,500: 360
#      Median value:  0.283161
#      Variance:      0.101145
# [2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000]
# Number of stars in Teff= 2500 - 2999 : 5
#      Median value:  1.0554
#      Variance:      0.368924
# Number of stars in Teff= 3000 - 3499 : 5
#      Median value:  1.1244
#      Variance:      0.380902
# Number of stars in Teff= 3500 - 3999 : 234
#      Median value:  1.15772
#      Variance:      0.282588
# Number of stars in Teff= 4000 - 4499 : 501
#      Median value:  1.14551
#      Variance:      0.266066
# Number of stars in Teff= 4500 - 4999 : 2880
#      Median value:  0.997642
#      Variance:      0.190006
# Number of stars in Teff= 5000 - 5499 : 3780
#      Median value:  0.810099
#      Variance:      0.147398
# Number of stars in Teff= 5500 - 5999 : 4931
#      Median value:  0.74942
#      Variance:      0.0964396
# Number of stars in Teff= 6000 - 6499 : 12708
#      Median value:  0.593711
#      Variance:      0.0974086
# Number of stars in Teff= 6500 - 6999 : 2157
#      Median value:  0.443846
#      Variance:      0.0537921
# Number of stars in Teff= 7000 - 7499 : 1033
#      Median value:  0.37453
#      Variance:      0.0846884
# Number of stars in Teff= 7500 - 7999 : 233
#      Median value:  0.303047
#      Variance:      0.067753
# Number of stars in Teff= 8000 - 8499 : 360
#      Median value:  0.283161
#      Variance:      0.101145
# Number of stars in Teff= 8500 - 8999 : 576
#      Median value:  0.220833
#      Variance:      0.105556
# Number of stars in Teff= 9000 - 9499 : 188
#      Median value:  0.15392
#      Variance:      0.100005
# Number of stars in Teff= 9500 - 9999 : 164
#      Median value:  0.141104
#      Variance:      0.174424
# Number of stars in Teff= 10000 - 10499 : 13
#      Median value:  0.125
#      Variance:      0.160365
# Number of stars in Teff= 10500 - 10999 : 35
#      Median value:  0.0451429
#      Variance:      0.118008
# Number of stars in Teff= 11000 - 11499 : 4
#      Median value:  0.1505
#      Variance:      0.236157
# Number of stars in Teff= 11500 - 11999 : 12
#      Median value:  0.209833
#      Variance:      0.366038
# Number of stars in Teff= 12000 - 12499 : 3
#      Median value:  0.254333
#      Variance:      0.423813
# [2749.5, 3249.5, 3749.5, 4249.5, 4749.5, 5249.5, 5749.5, 6249.5, 6749.5, 7249.5, 7749.5, 8249.5, 8749.5, 9249.5, 9749.5, 10249.5, 10749.5, 11249.5, 11749.5, 12249.5]
# [1.0553999, 1.1243999, 1.1577221, 1.1455052, 0.99764222, 0.81009889, 0.7494204, 0.59371066, 0.44384608, 0.37453043, 0.30304721, 0.2831611, 0.22083335, 0.1539202, 0.14110366, 0.12500003, 0.045142855, 0.15050006, 0.20983338, 0.2543335]
