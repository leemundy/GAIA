# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.ma as ma
from astropy.table import Table
from scipy.spatial import distance
from scipy import spatial
from scipy.spatial import KDTree
import time
import matplotlib.path as mpltPath
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 30
x = np.linspace(0,10,N)
y = np.linspace(0,10,N)
z = np.linspace(0,10,N)

data = np.random.rand(3,40)*10
data = np.transpose(data)

X, Y, Z = np.meshgrid(x,y,z)
grid3d = np.array([X,Y,Z])
grid3d = np.transpose(grid3d)
print(grid3d[0])
print('Finished building Grid\n')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X,Y,Z,s=4.0,marker='s',alpha=0.1)
ax.scatter(data[:,0],data[:,1],data[:,2],c='k',s=30.0)
plt.show()
# Out:
# [[[  0.           0.           0.        ]
#   [  0.           0.34482759   0.        ]
#   [  0.           0.68965517   0.        ]
#   ...,
#   [  0.           9.31034483   0.        ]
#   [  0.           9.65517241   0.        ]
#   [  0.          10.           0.        ]]
#
#  [[  0.34482759   0.           0.        ]
#   [  0.34482759   0.34482759   0.        ]
#   [  0.34482759   0.68965517   0.        ]
#   ...,
#   [  0.34482759   9.31034483   0.        ]
#   [  0.34482759   9.65517241   0.        ]
#   [  0.34482759  10.           0.        ]]
#
#  [[  0.68965517   0.           0.        ]
#   [  0.68965517   0.34482759   0.        ]
#   [  0.68965517   0.68965517   0.        ]
#   ...,
#   [  0.68965517   9.31034483   0.        ]
#   [  0.68965517   9.65517241   0.        ]
#   [  0.68965517  10.           0.        ]]
#
#  ...,
#  [[  9.31034483   0.           0.        ]
#   [  9.31034483   0.34482759   0.        ]
#   [  9.31034483   0.68965517   0.        ]
#   ...,
# ...

# %%
S = np.array([[1,1,1],[2,2,2],[3,3,3]])
D = np.array([[5,5,5],[6,6,6],[7,7,7],[8,8,8],[9,9,9],[10,10,10]])

# %%
X = np.array(X)
#print(X[0])
Y = np.array(Y)
Z = np.array(Z)
XYZ = [X,Y,Z]

#XYZ = np.transpose(XYZ)
XYZ = np.transpose(XYZ)
print(XYZ[0,0,0],'\n\n')
print(np.size(XYZ))
grid3d = XYZ[0,0,0]
for i in range(len(XYZ)):
    for x in range(1,len(XYZ)):
        X
        np.concatenate((a,b),axis=0)

# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.scatter(grid3d[:,0],grid3d[:,1],grid3d[:,2],s=4.0,marker='s',alpha=0.1)
# plt.show()
# Out:
# [ 0.  0.  0.]
#
#
# 81000

# %%
N = 20

tree = KDTree(data)
dist,ind = tree.query(grid3d,k=3)
dist = np.array(grid3d)
#print(grid3d)

# %%
distArray = []
for d in range(len(dist)):
    distArray.append(dist[d][N])
print('LENGTH OF DISTARRAY:',len(distArray))
print('\nLength of distArray:',len(distArray))    
distArray = np.array(distArray)
# print(data[0],grid3d[0],'\n')
# print(distArray[0])
print(distArray)
# Out:
# LENGTH OF DISTARRAY: 30
#
# Length of distArray: 30
# [[[  6.89655172   0.           0.        ]
#   [  6.89655172   0.34482759   0.        ]
#   [  6.89655172   0.68965517   0.        ]
#   ...,
#   [  6.89655172   9.31034483   0.        ]
#   [  6.89655172   9.65517241   0.        ]
#   [  6.89655172  10.           0.        ]]
#
#  [[  6.89655172   0.           0.34482759]
#   [  6.89655172   0.34482759   0.34482759]
#   [  6.89655172   0.68965517   0.34482759]
#   ...,
#   [  6.89655172   9.31034483   0.34482759]
#   [  6.89655172   9.65517241   0.34482759]
#   [  6.89655172  10.           0.34482759]]
#
#  [[  6.89655172   0.           0.68965517]
#   [  6.89655172   0.34482759   0.68965517]
#   [  6.89655172   0.68965517   0.68965517]
#   ...,
#   [  6.89655172   9.31034483   0.68965517]
#   [  6.89655172   9.65517241   0.68965517]
#   [  6.89655172  10.           0.68965517]]
#
#  ...,
#  [[  6.89655172   0.           9.31034483]
#   [  6.89655172   0.34482759   9.31034483]
# ...

# %%
a = np.array([[1,5,9],[2,6,10],[1,1,1]])
b = np.array([[3,7,11],[4,8,12]])
np.concatenate((a,b),axis=0)
# Out:
# array([[ 1,  5,  9],
#        [ 2,  6, 10],
#        [ 1,  1,  1],
#        [ 3,  7, 11],
#        [ 4,  8, 12]])
