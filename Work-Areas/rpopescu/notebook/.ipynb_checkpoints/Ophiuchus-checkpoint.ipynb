# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
from astropy.table import Table
t = Table.read('../../../../../../Downloads/vizier_votable(5).vot', format='votable')

print("Finished reading Table. Read ",len(t['__Gmag_'])," sources")
# Out:
# WARNING: W27: ../../../../../../Downloads/vizier_votable(5).vot:52:2: W27: COOSYS deprecated in VOTable 1.2 [astropy.io.votable.tree]
# WARNING: W03: ../../../../../../Downloads/vizier_votable(5).vot:94:4: W03: Implicitly generating an ID from a name '<FG>' -> '__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: ../../../../../../Downloads/vizier_votable(5).vot:94:4: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: ../../../../../../Downloads/vizier_votable(5).vot:98:4: W03: Implicitly generating an ID from a name 'e_<FG>' -> 'e__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: ../../../../../../Downloads/vizier_votable(5).vot:98:4: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: ../../../../../../Downloads/vizier_votable(5).vot:102:4: W03: Implicitly generating an ID from a name '<Gmag>' -> '__Gmag_' [astropy.io.votable.xmlutil]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:110:82: W51: Value '4126704706569381760' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:111:82: W51: Value '4126704702277992576' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:112:82: W51: Value '4126704702282615296' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:113:83: W51: Value '4126704912729402112' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:114:82: W51: Value '4126704908436423296' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:115:82: W51: Value '4126704908441041792' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:116:82: W51: Value '4126704912727819008' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:117:82: W51: Value '4126704908441044480' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:118:83: W51: Value '4126704908441046656' is out of range for a 16-bit integer field [astropy.io.votable.converters]
# WARNING: W51: ../../../../../../Downloads/vizier_votable(5).vot:119:83: W51: Value '4126704908441045120' is out of range for a 16-bit integer field (suppressing further warnings of this type...) [astropy.io.votable.converters]
# Finished reading Table. Read  503325  sources

# %%
print("The astropy reader loads the data into the following variable names:")
print(t.colnames)
# Out:
# The astropy reader loads the data into the following variable names:
# ['RA_ICRS', 'e_RA_ICRS', 'DE_ICRS', 'e_DE_ICRS', 'Source', 'Plx', 'pmRA', 'pmDE', 'RADEcor', 'Dup', '__FG_', 'e__FG_', '__Gmag_', 'Var']

# %%
RA = t['RA_ICRS']
DE = t['DE_ICRS']
plx = t['Plx']
num = len(RA)

# %%
X1 = np.zeros(num)
Y1 = np.zeros(num)
for i in range(0,num):
    X1[i] = RA[i]
    Y1[i] = DE[i]
X = np.column_stack((X1,Y1))
print(len(X))
# Out:
# 503325

# %%
plt.scatter(RA,DE, s = 1)
plt.show()

# %%
RAmin = min(RA)
RAmax = max(RA)
DEmin = min(DE)
DEmax = max(DE)
RA_range = RAmax - RAmin
DE_range = DEmax - DEmin
area = RA_range*DE_range
num = len(RA)
density = num/area
print(RA_range)
print(DE_range)
print(area)
print(num)
print(density)
# Out:
# 5.9999703714
# 2.9999811586
# 17.9997980664
# 503325
# 27962.8137018

# %%
#create mapping function
def distance_map(data,pixel_count,RAmin, RAmax, DEmin, DEmax, neighbor, scatter):
    from scipy.spatial import KDTree

    #use KD tree to find distances to nearest neighbor stars
    tree = KDTree(data)
    
    dRA = (RAmax - RAmin)/pixel_count
    dDE = (DEmax - DEmin)/pixel_count

    #create array of coordinates for image background
    for i in range(0,pixel_count):
        for j in range(0,pixel_count):
            if (i==0 and j == 0):
                array4 = np.array([RAmin,DEmin])
            else:
                array3 = [RAmin+i*dRA,DEmin+j*dDE]
                array4 = np.vstack((array4,array3))

    #find nearest neighbor distances to background points
    image = tree.query(array4,k=neighbor+1)

    #change array of background points so it is 100 x 100
    dist2 = image[0][:,neighbor-1]
    dist2 = np.resize(dist2,(pixel_count,pixel_count))
    dist2 = np.rot90(dist2, k=1, axes=(1,0))
    dist2 = np.fliplr(dist2)

    #display map 
    plt.imshow(dist2, origin='lower')
    if (scatter == True):
        plt.scatter(data[:,0],data[:,1],s = 2,c = 'w')
    plt.show()
    return

# %%
import timeit
start_time = timeit.default_timer()
    
#range of coordinates
pixel_count = 100
scatter = False
neighbor = 5

distance_map(X,pixel_count,RAmin, RAmax, DEmin, DEmax, neighbor, scatter)
num = timeit.default_timer() - start_time
print('Elapsed time is: ' + str(num))
# Out:
# Elapsed time is: 7.349188921973109

# %%
import timeit
start_time = timeit.default_timer()
    
#range of coordinates
pixel_count = 256
scatter = False
neighbor = 5

distance_map(X,pixel_count,RAmin, RAmax, DEmin, DEmax, neighbor, scatter)
num = timeit.default_timer() - start_time
print('Elapsed time is: ' + str(num))
# Out:
# Elapsed time is: 34.27730053476989

# %%
import timeit
start_time = timeit.default_timer()
    
#range of coordinates
pixel_count = 256
scatter = False
neighbor = 10

distance_map(X,pixel_count,RAmin, RAmax, DEmin, DEmax, neighbor, scatter)
num = timeit.default_timer() - start_time
print('Elapsed time is: ' + str(num))
# Out:
# Elapsed time is: 38.96231385320425

# %%
import timeit
start_time = timeit.default_timer()
    
#range of coordinates
pixel_count = 256
scatter = False
neighbor = 20

distance_map(X,pixel_count,RAmin, RAmax, DEmin, DEmax, neighbor, scatter)
num = timeit.default_timer() - start_time
print('Elapsed time is: ' + str(num))
# Out:
# Elapsed time is: 48.79249772801995

# %%
#Find number of stars with parallaxes
plx_count = 0
parallaxes = np.array([])
plx_indices = np.array([])
for i in range(len(plx)):
    if (plx[i] > 0):
        plx_count = plx_count+1
        parallaxes = np.append(parallaxes, plx[i])
        plx_indices = np.append(plx_indices, i)
print(plx_count)
distances = 1/(parallaxes/1000)
# Out:
# 240

# %%
print(distances)
# Out:
# [    84.81764234    144.30014787    112.23344749    400.            724.63768366
#     452.48867997    751.87967499    769.23079745   5555.5553348     500.
#     378.78786374    735.29410991   1851.85177827    308.6419744
#     460.82947689    606.06061482    636.94265388    632.91137521
#     465.11625844   1052.63159216   3703.70355653    602.40965067
#     526.31579608   1428.5714529     432.90044362    518.13472911
#    1149.42528106    259.06736455   1369.86297791   2127.65957986
#     549.45053362    934.57939344    518.13472911    497.51244017
#     285.71428571    515.46390232    273.22403731    502.51256041
#     492.61084438    534.75935693   1136.36364252   1111.11114055
#     210.52631579    694.44441685    826.44625494   1351.35133394
#     507.61420583    390.62500873     90.41590977    769.23079745
