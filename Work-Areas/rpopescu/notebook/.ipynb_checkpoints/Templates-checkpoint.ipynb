# %%
#Create G-J templates from GAIA data crossed with 2Masss

# %%
# %matplotlib inline
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import math
import pandas as pd

# %%
def cleanData(t,QFlags,Jmag,Kmag,Hmag,dup,Source,s1):
    #Masks data values 
    
    # mask all data that does not have a Qfl value of A
    for i in range(0,len(QFlags)):
        if(QFlags[i][0] == ord("A")):
            Jmag.mask[i] = False
        else:
             Jmag.mask[i] = True
            
    for i in range(0,len(QFlags)):
        if(QFlags[i][2] == ord("A")):
            Kmag.mask[i] = False
        else:
            Kmag.mask[i] = True  
        
    for i in range(0,len(QFlags)):
        if(QFlags[i][1] == ord("A")):
            Hmag.mask[i] = False
        else:
            Hmag.mask[i] = True
    
    #mask all values with dup = 1
    imask = 0
    for i in range(0,len(dup)):
        if (dup[i] > 0.5):
            imask = imask + 1
            row = t[i]
            idx = row._index
            cols = row._table.columns.values()
            for col in cols:
                col.mask[i] = True
    for i in range(0,len(dup)):
        if(dup[i] > 0.5):
            print(i,dup[i])
    print("Masked ",imask," rows in which dup is equal to 1")
    
    #remove dupliacte matches
    Test = Source.compressed()
    unique = set()
    Gdups = set()

    for i in range(0,len(Test)):
        if(Test[i] in unique):
            print("GAIA Duplicate Source: ",Test[i])
            Gdups.add(Test[i])
        else:
            unique.add(Test[i])
            last = Test[i]
    print("Finished GAIA Duplicate Check. Found: ", len(Gdups))

    for i in range(0,len(Source)):
        if(Source.mask[i] == False):
            Name = Source[i]
            if(Name in Gdups):
                row = t[i]
                idx = row._index
                cols = row._table.columns.values()
                for col in cols:
                    col.mask[i] = True
    print("Finished masking all GAIA duplicates. All sources involved")
    TwoM = t["_2MASS"]
    unique = set()
    Tdups = set()
    Test = TwoM.compressed()
    for i in range(0,len(Test)):
        if(Test[i] in unique):
            print("2MASS Duplicate Source: ",Test[i])
            Tdups.add(Test[i])
        else:
            unique.add(Test[i])
            last = Test[i]
    print("Finished 2MASS Duplicate Check. Found: ", len(Tdups))

    for i in range(0,len(Source)):
        if(Source.mask[i] == False):
            Name = Source[i]
            if(Name in Tdups):
                print(Source[i],s1[i],Gmag[i],Vmag[i]-Gmag[i],Jmag[i],Kmag[i],TwoM[i])
                
    #masked rows with J-G greater than 5 sigma from mean
    J_G = Jmag-Gmag
    JGmean = np.mean(J_G)
    JGstd = np.std(J_G)
    imask = 0
    for i in range(0,len(J_G)):
        if(abs(J_G[i] - JGmean) > 5*JGstd):
            imask = imask + 1
            row = t[i]
            idx = row._index
            cols = row._table.columns.values()
            for col in cols:
                col.mask[i] = True
    print("Masked ",imask," rows based on J-G color > 5 sigma from mean")
    
    return t

# %%
def AbsoluteMagnitudes(plx,Vmag,Bmag,Gmag,Jmag,Hmag,Kmag):
    #Calculate distance, and absolute magnitudes
    
    Dist = ma.array([])
    Vmags = ma.array([])
    Bmags = ma.array([])
    Gmags = ma.array([])
    Jmags = ma.array([])
    Hmags = ma.array([])
    Kmags = ma.array([])

    Dist = 1000./plx
    Vmags = Vmag - 5 * np.log10(Dist) + 5
    Bmags = Bmag - 5 * np.log10(Dist) + 5
    Gmags = Gmag - 5 * np.log10(Dist) + 5
    Jmags = Jmag -5 * np.log10(Dist) + 5
    Hmags = Hmag - 5 * np.log10(Dist) + 5
    Kmags = Kmag - 5 * np.log10(Dist) + 5
    
    return Dist,Vmags,Bmags,Gmags,Jmags,Hmags,Kmags

# %%
def ColorClassification(Gmags,Kmags):    
    #split the stars into different categories based on G-K
    
    G_K = Gmags-Kmags
    color = np.ones(len(G_K))*1000
    #colors = np.arange(0.1,3,0.1)
    colors = [0.5,1,1.5,2,2.5,3]
    for i in range(len(colors)):
        for j in range(len(G_K)):
            if (i == 0):
                if (G_K[j] <= colors[i]):
                    color[j] = colors[i]
            elif(G_K[j] <= colors[i] and G_K[j] > colors[i-1]):
                color[j] = colors[i]
    return color,colors

# %%
def CreateTemplates(color,colors,Vmags,Bmags,Gmags,Jmags,Hmags,Kmags):
    #for each color class, a template is created of the absolute magnitudes of the stars and their color indices
    
    G_K = Gmags-Kmags
    #wavelengths of color bands
    wvl = [420, 477, 1235, 1662, 2159]
    wvl2 = [420, 477, 673,1235, 1662, 2159]
    avg_colors = np.array([])
    err_colors = np.array([])
    stars = np.array([])
    for c in colors:
        #create array of values for color indices and absolute magnitudes
        G_B_array = ma.array([])
        G_V_array = ma.array([])
        G_J_array = ma.array([])
        G_H_array = ma.array([])
        G_K_array = ma.array([])
        B = ma.array([])
        V = ma.array([])
        G = ma.array([])
        J = ma.array([])
        H = ma.array([])
        K = ma.array([])
        star_count = 0
        #fill arrays with values if the values are part of the color category
        for i in range(len(G_K)):
            if (color[i] == c):
                G_B_array = np.append(G_B_array,Gmags[i]-Bmags[i])
                G_V_array = np.append(G_V_array,Gmags[i]-Vmags[i])
                G_J_array = np.append(G_J_array,Gmags[i]-Jmags[i])
                G_H_array = np.append(G_H_array,Gmags[i]-Hmags[i])
                G_K_array = np.append(G_K_array,Gmags[i]-Kmags[i])
                B = np.append(B,Bmags[i])
                V = np.append(V,Vmags[i])
                G = np.append(G,Gmags[i])
                J = np.append(J,Jmags[i])
                H = np.append(H,Hmags[i])
                K = np.append(K,Kmags[i])
                star_count = star_count +1
        #average G-K value
        avg_colors = np.append(avg_colors,np.mean(G_K_array))
        err_colors = np.append(err_colors,np.std(G_K_array))
        #number of stars per color
        stars = np.append(stars,star_count)
        #relative SED
        mag_array = [np.mean(G_B_array), np.mean(G_V_array),\
                     np.mean(G_J_array), np.mean(G_H_array), np.mean(G_K_array)]
        std_array = [np.std(G_B_array), np.std(G_V_array), \
                     np.std(G_J_array), np.std(G_H_array), np.std(G_K_array)]
        #absolute SED
        mag_array2 = [np.mean(B), np.mean(V), np.mean(G), \
                      np.mean(J), np.mean(H), np.mean(K)]
        std_array2 = [np.std(B), np.std(V), np.std(G), \
                      np.std(J), np.std(H), np.std(K)]
        #add standard deviation error
        val = np.sqrt(len(G_B_array))
        #std_array = std_array/val
        val2 = np.sqrt(len(B))
        #std_array2 = std_array2/val2
        #stack SEDs
        if (c == colors[0]):
            color_mags = np.array(mag_array)
            color_std = np.array(std_array)
            abs_color_mags = np.array(mag_array2)
            abs_color_std = np.array(std_array2)
        else:
            color_mags = np.vstack((color_mags,mag_array))
            color_std = np.vstack((color_std,std_array))
            abs_color_mags = np.vstack((abs_color_mags, mag_array2))
            abs_color_std = np.vstack((abs_color_mags, std_array2))
    return avg_colors,err_colors,color_mags,color_std,abs_color_mags,abs_color_std

# %%
def CreatePlots(colors,abs_colors_mags,abs_color_std,color_mags,color_std):
    #create SED and Relative SED plots
    
    wvl = [420, 477, 1235, 1662, 2159]
    wvl2 = [420, 477, 673,1235, 1662, 2159]
    
    #plot average absolute magnitude in each filter for each color 
    ax = plt.subplot(111)
    for i in range(len(colors)):
        ax.errorbar(wvl2, abs_color_mags[i,:], yerr = abs_color_std[i,:], linestyle = '-', marker = 'o',label = str(colors[i]))
    ax.set_xlabel('Effective Wavelength (nm)')
    ax.set_ylabel('Average Absolute Magnitude')
    ax.set_title('Spectral Energy Distribution for Main Sequence Stars')
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    
    #plot average color index in each filter for each color 
    ax2 = plt.subplot(111)
    for i in range(len(colors)):
        ax2.errorbar(wvl, color_mags[i,:], yerr = color_std[i,:], linestyle = '-', marker = 'o',label = str(colors[i]))
    ax2.set_xlabel('Effective Wavelength (nm)')
    ax2.set_ylabel('Average Color Index')
    ax2.set_title('Spectral Energy Distribution for Main Sequence Stars')
    box2 = ax.get_position()
    ax2.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    
    return

# %%
def PrintToFile(colors,avg_colors,err_colors,color_mags,color_std):
    #csv table
    #df = pd.DataFrame({"colors" : colors, "avg_colors" : avg_colors, "err_colors" : err_colors,\
    #                   "color_mags" : color_mags, "color_std" : color_std})
    #df.to_csv("../G_KTemplates.csv", index=False)
    
    download_dir = "../G_KTemplates.csv"
    csv = open(download_dir, "w") 

    columnTitleRow = "colors,avg_colors,err_colors,G_B,G_V,G_H,G_J,G_K,G_B_err,G_V_err,G_H_err,G_J_err,G_K_err"
    csv.write(columnTitleRow)

    for i in range(len(colors)):
        color = str(colors[i])
        avg_col = str(avg_colors[i])
        err_col = str(err_colors[i])
        G_B = str(color_mags[i,0])
        G_V = str(color_mags[i,1])
        G_H = str(color_mags[i,2])
        G_J = str(color_mags[i,3])
        G_K = str(color_mags[i,4])
        G_B_err = str(color_std[i,0])
        G_V_err = str(color_std[i,1])
        G_H_err = str(color_std[i,2])
        G_J_err = str(color_std[i,3])
        G_K_err = str(color_std[i,4])
        row = color + "," + avg_col + "," + err_col + "," + G_B + "," + G_V + "," + G_H + "," \
               + G_J + "," + G_K + "," + G_B_err + "," + + G_V_err + "," + G_H_err + "," + G_J_err + "," \
               + G_K_err + "\n"
        csv.write(row)
    return

# %%
from astropy.table import Table
t = Table.read('../dr1_200pc_2Mass.vot', format='votable')

print("The astropy reader loads the data into the following variable names:")
print(t.colnames)
print("\nThe number of stars is " + str(len(t)))

#Rename columns
Source = t["Source"]
Gmag = t["__Gmag_"]
#Using Gmag in place of Vmag and Bmag to calculate Vmags and Bmags
Vmag = t["__Gmag_"]
Bmag = t["__Gmag_"]
Jmag = t["Jmag"]
Hmag = t["Hmag"]
Kmag = t["Kmag"]
QFlags = t["Qfl"]
s1= t["d_arcsec"]
plx = t['Plx']
dup = t['Dup']
# Out:
# WARNING: W03: ../dr1_200pc_2Mass.vot:19:0: W03: Implicitly generating an ID from a name '<FG>' -> '__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: ../dr1_200pc_2Mass.vot:19:0: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: ../dr1_200pc_2Mass.vot:20:0: W03: Implicitly generating an ID from a name 'e_<FG>' -> 'e__FG_' [astropy.io.votable.xmlutil]
# WARNING: W50: ../dr1_200pc_2Mass.vot:20:0: W50: Invalid unit string 'e-/s' [astropy.io.votable.tree]
# WARNING: W03: ../dr1_200pc_2Mass.vot:21:0: W03: Implicitly generating an ID from a name '<Gmag>' -> '__Gmag_' [astropy.io.votable.xmlutil]
# WARNING: W03: ../dr1_200pc_2Mass.vot:24:0: W03: Implicitly generating an ID from a name '2MASS' -> '_2MASS' [astropy.io.votable.xmlutil]
# The astropy reader loads the data into the following variable names:
# ['d_arcsec', 'RA_ICRS', 'e_RA_ICRS', 'DE_ICRS', 'e_DE_ICRS', 'Source', 'Plx', 'pmRA', 'pmDE', 'RADEcor', 'Dup', '__FG_', 'e__FG_', '__Gmag_', 'Var', '_2MASS', 'RAJ2000', 'DEJ2000', 'errHalfMaj', 'errHalfMin', 'errPosAng', 'Jmag', 'Hmag', 'Kmag', 'e_Jmag', 'e_Hmag', 'e_Kmag', 'Qfl', 'Rfl', 'X', 'MeasureJD']
#
# The number of stars is 191206

# %%
#I get [IndexError: too many indices for array] if I do not reinput the table t? 

t = cleanData(t,QFlags,Jmag,Kmag,Hmag,dup,Source,s1)
Dist,Vmags,Bmags,Gmags,Jmags,Hmags,Kmags = AbsoluteMagnitudes(plx,Vmag,Bmag,Gmag,Jmag,Hmag,Kmag)
color,colors = ColorClassification(Gmags,Kmags)
avg_colors,err_colors,color_mags,color_std,abs_color_mags,abs_color_std = CreateTemplates(color,colors,Vmags,Bmags,Gmags,Jmags,Hmags,Kmags)
# Out:
# Masked  72230  rows in which dup is equal to 1
# GAIA Duplicate Source:  5555073729568686592
# GAIA Duplicate Source:  5859121851795522560
# GAIA Duplicate Source:  101700874199870208
# GAIA Duplicate Source:  5621620502608043264
# GAIA Duplicate Source:  4340260028239519232
# GAIA Duplicate Source:  6038042561484950016
# GAIA Duplicate Source:  1147294066657043456
# GAIA Duplicate Source:  4328234841366192000
# GAIA Duplicate Source:  3262302333060747392
# GAIA Duplicate Source:  3416890094513036800
# GAIA Duplicate Source:  2984035009725892352
# GAIA Duplicate Source:  3324242049302232832
# GAIA Duplicate Source:  1365860691743696512
# GAIA Duplicate Source:  6619616420815047296
# GAIA Duplicate Source:  5987472963708064256
# GAIA Duplicate Source:  2104443299690769664
# GAIA Duplicate Source:  1380512921133521792
# GAIA Duplicate Source:  953018608366138496
# GAIA Duplicate Source:  4682948802998169600
# GAIA Duplicate Source:  5853738917743902080
# GAIA Duplicate Source:  3153870076878137600
# GAIA Duplicate Source:  373553303101170176
# GAIA Duplicate Source:  2253005806143146240
# GAIA Duplicate Source:  5819883202381670272
# GAIA Duplicate Source:  6808548871070663040
# GAIA Duplicate Source:  4330218738298132480
# GAIA Duplicate Source:  6655327390255709824
# GAIA Duplicate Source:  6203072522305639808
# GAIA Duplicate Source:  6203072522305639808
# GAIA Duplicate Source:  4373226616655508480
# GAIA Duplicate Source:  6126665328987711872
# GAIA Duplicate Source:  4109477141773741440
# GAIA Duplicate Source:  3237277792010166656
# GAIA Duplicate Source:  5964068312524360576
# GAIA Duplicate Source:  1953933901743715328
# GAIA Duplicate Source:  6347187779102055424
# GAIA Duplicate Source:  4152544221959604736
# GAIA Duplicate Source:  3807348320171919872
# GAIA Duplicate Source:  4185413847197314432
# GAIA Duplicate Source:  6103661312351439616
# GAIA Duplicate Source:  4658816584352013056
# GAIA Duplicate Source:  4123996124102195584
# GAIA Duplicate Source:  4483837933085801472
# GAIA Duplicate Source:  141118194257249408
# GAIA Duplicate Source:  2501375140575931264
# GAIA Duplicate Source:  4801645962299716736
# GAIA Duplicate Source:  181870939905088000
# GAIA Duplicate Source:  1732147597374328704
# GAIA Duplicate Source:  575858666608004224
# GAIA Duplicate Source:  5472813801495593600
# GAIA Duplicate Source:  6344759267153056128
# GAIA Duplicate Source:  3389026786238193152
# GAIA Duplicate Source:  181870939905524480
# GAIA Duplicate Source:  4626736580265042176
# GAIA Duplicate Source:  2613694273442289024
# GAIA Duplicate Source:  3327813606666376192
# GAIA Duplicate Source:  3327813606666376192
# GAIA Duplicate Source:  4263758586158517376
# GAIA Duplicate Source:  2896176196645559552
# GAIA Duplicate Source:  1950349459478066048
# GAIA Duplicate Source:  6623230171937768576
# GAIA Duplicate Source:  6208356019274293504
# GAIA Duplicate Source:  4184157758238521088
# GAIA Duplicate Source:  2573940227949356416
# GAIA Duplicate Source:  6132630523167092736
# GAIA Duplicate Source:  1159115500283269120
# GAIA Duplicate Source:  1014076894238815104
# GAIA Duplicate Source:  432803545180414848
# GAIA Duplicate Source:  6785793275342096256
# GAIA Duplicate Source:  5163910270279750272
# GAIA Duplicate Source:  587072791858415232
# GAIA Duplicate Source:  3183460820998817280
# GAIA Duplicate Source:  2595355587722530304
# GAIA Duplicate Source:  2087946192872348160
# GAIA Duplicate Source:  3248442439236776960
# GAIA Duplicate Source:  6100689023184967680
# GAIA Duplicate Source:  6908358653989846912
# GAIA Duplicate Source:  4347690699617993472
# GAIA Duplicate Source:  6273176799578060672
# GAIA Duplicate Source:  5133580860502607104
# GAIA Duplicate Source:  4511840363942102912
# GAIA Duplicate Source:  10391931070937984
# GAIA Duplicate Source:  2263957560431577088
# GAIA Duplicate Source:  3030925504157855360
# GAIA Duplicate Source:  6612935100970820096
# GAIA Duplicate Source:  2296570415341132032
# GAIA Duplicate Source:  3178164507848709248
# GAIA Duplicate Source:  520779250090041088
# GAIA Duplicate Source:  1698378777786064896
# GAIA Duplicate Source:  338871888862260992
# GAIA Duplicate Source:  5675318107888596608
# GAIA Duplicate Source:  4098631971397272064
# GAIA Duplicate Source:  3824450845584397056
# GAIA Duplicate Source:  5555028065476113792
# GAIA Duplicate Source:  6161505072902638848
# GAIA Duplicate Source:  4070125689336255488
# GAIA Duplicate Source:  4102312174253539584
# GAIA Duplicate Source:  1837550183626334848
# GAIA Duplicate Source:  1278191406980008576
# GAIA Duplicate Source:  3812512966805709184
# GAIA Duplicate Source:  2565447153459666048
# GAIA Duplicate Source:  3120808518144739072
# GAIA Duplicate Source:  4278159852029055616
# GAIA Duplicate Source:  6132680757104283520
# GAIA Duplicate Source:  1136553212444003200
# GAIA Duplicate Source:  2263957560430977792
# GAIA Duplicate Source:  6179370212707616256
# GAIA Duplicate Source:  4388472307449286912
# GAIA Duplicate Source:  2691000076997759360
# GAIA Duplicate Source:  2305597096566352512
# GAIA Duplicate Source:  6572742350337698304
# GAIA Duplicate Source:  6085878532838271360
# GAIA Duplicate Source:  3368553639212135424
# GAIA Duplicate Source:  3785073073586186112
# GAIA Duplicate Source:  5797006454215874176
# GAIA Duplicate Source:  404261116677626496
# GAIA Duplicate Source:  6506475196847763712
# GAIA Duplicate Source:  1078374307005998592
# GAIA Duplicate Source:  5541723631182238976
# GAIA Duplicate Source:  3361046345615322880
# GAIA Duplicate Source:  173226579487630592
# GAIA Duplicate Source:  6274653306256074496
# GAIA Duplicate Source:  6657758169946168576
# GAIA Duplicate Source:  6613740871193995648
# GAIA Duplicate Source:  5576143945771025024
# GAIA Duplicate Source:  2040633279815951616
# GAIA Duplicate Source:  1366974840619147264
# GAIA Duplicate Source:  3874697290023399424
# GAIA Duplicate Source:  3111837190460276864
# GAIA Duplicate Source:  3022236888397268992
# GAIA Duplicate Source:  5327173693872070912
# GAIA Duplicate Source:  351835302754498560
# GAIA Duplicate Source:  5849179071228490880
# GAIA Duplicate Source:  2886312202955692288
# GAIA Duplicate Source:  604129653178777472
# GAIA Duplicate Source:  1998814729438500608
# GAIA Duplicate Source:  2712661383778384512
# GAIA Duplicate Source:  342111531154035072
# GAIA Duplicate Source:  3567302013883020928
# GAIA Duplicate Source:  3394868422796949632
# GAIA Duplicate Source:  188916954015258496
# GAIA Duplicate Source:  4766607859616203520
# GAIA Duplicate Source:  2379646971314317056
# GAIA Duplicate Source:  2968856217344027904
# GAIA Duplicate Source:  911067498122796672
# GAIA Duplicate Source:  5927128948076037504
# GAIA Duplicate Source:  56361515796027648
# GAIA Duplicate Source:  222237722612352768
# GAIA Duplicate Source:  6113353026316542464
# GAIA Duplicate Source:  2707233850786086144
# GAIA Duplicate Source:  3924275815507830528
# GAIA Duplicate Source:  6284251389929712128
# GAIA Duplicate Source:  6692161201584173184
# GAIA Duplicate Source:  4329324045072596992
# GAIA Duplicate Source:  4816698620080673280
# GAIA Duplicate Source:  2028211581558734848
# GAIA Duplicate Source:  5669303607485276160
# GAIA Duplicate Source:  6252084833661572224
# GAIA Duplicate Source:  5830541352703013760
# GAIA Duplicate Source:  3210250284370805376
# GAIA Duplicate Source:  5830288877349707776
# GAIA Duplicate Source:  6734942477465317888
# GAIA Duplicate Source:  1105013034205692288
# GAIA Duplicate Source:  3846938916389545344
# GAIA Duplicate Source:  2276317582954904448
# GAIA Duplicate Source:  6017594153472943360
# GAIA Duplicate Source:  879144243162348288
# GAIA Duplicate Source:  2969632884870786304
# GAIA Duplicate Source:  6115578884527661440
# GAIA Duplicate Source:  6339568816356105728
# GAIA Duplicate Source:  2654956230413394944
# GAIA Duplicate Source:  1414509064750524928
# GAIA Duplicate Source:  2022354826714676608
# GAIA Duplicate Source:  3848160748685879168
# GAIA Duplicate Source:  5209365627160857856
# GAIA Duplicate Source:  5715484195366203904
# GAIA Duplicate Source:  3066081598182614400
# GAIA Duplicate Source:  2498832038900176000
# GAIA Duplicate Source:  4493709554640448512
# GAIA Duplicate Source:  427662331889257088
# GAIA Duplicate Source:  2949489522615174272
# GAIA Duplicate Source:  2653835140869927424
# GAIA Duplicate Source:  3104968403880684160
# GAIA Duplicate Source:  2389294498652881536
# GAIA Duplicate Source:  2185699889045148672
# GAIA Duplicate Source:  6184487168023648256
# GAIA Duplicate Source:  3314011952598152704
# GAIA Duplicate Source:  6825243546388276224
# GAIA Duplicate Source:  1725478028559155840
# GAIA Duplicate Source:  6424405209409136000
# GAIA Duplicate Source:  5933975813145822976
# GAIA Duplicate Source:  3776005195034098048
# GAIA Duplicate Source:  2700140695116618880
# GAIA Duplicate Source:  6715886566566316544
# GAIA Duplicate Source:  6743904837267050368
# GAIA Duplicate Source:  4110101355140482816
# GAIA Duplicate Source:  3428894253228690816
# GAIA Duplicate Source:  6390154838089770496
# GAIA Duplicate Source:  3135344096223169280
# GAIA Duplicate Source:  956699257899874048
# GAIA Duplicate Source:  3465579355609772544
# GAIA Duplicate Source:  4097002323363211776
# GAIA Duplicate Source:  3722883562048219520
# GAIA Duplicate Source:  3473965090276202880
# GAIA Duplicate Source:  2331009559063341696
# GAIA Duplicate Source:  5237988938491056640
# GAIA Duplicate Source:  2058751272937906048
# GAIA Duplicate Source:  2755680429049643136
# GAIA Duplicate Source:  657719849916581888
# GAIA Duplicate Source:  3255252986058161408
# GAIA Duplicate Source:  3139013235245629440
# GAIA Duplicate Source:  642089845451179008
# GAIA Duplicate Source:  2064457738280481664
# GAIA Duplicate Source:  5140648418166947328
# GAIA Duplicate Source:  2787122819471974144
# GAIA Duplicate Source:  3954113674867640832
# GAIA Duplicate Source:  5834992313211912832
# GAIA Duplicate Source:  4366561033569972864
# GAIA Duplicate Source:  6674187588082866048
# GAIA Duplicate Source:  2090503519475350400
# GAIA Duplicate Source:  5325067304471276800
# GAIA Duplicate Source:  6137782697214772096
# GAIA Duplicate Source:  2748301434717043840
# GAIA Duplicate Source:  6131956453818754560
# GAIA Duplicate Source:  1944005208665984384
# GAIA Duplicate Source:  233942092611259776
# GAIA Duplicate Source:  2623950036869856256
# GAIA Duplicate Source:  11528207618987776
# GAIA Duplicate Source:  3976965615301919872
# GAIA Duplicate Source:  4448637996035843584
# GAIA Duplicate Source:  6774943775637803520
# GAIA Duplicate Source:  4119638793878805248
# GAIA Duplicate Source:  1994240142592996736
# GAIA Duplicate Source:  3516731625831072768
# GAIA Duplicate Source:  396303710508033536
# GAIA Duplicate Source:  2300148157457794688
# GAIA Duplicate Source:  1698753367654209792
# GAIA Duplicate Source:  2635091663072052480
# GAIA Duplicate Source:  6154783620881532288
# GAIA Duplicate Source:  6599467973314887552
# GAIA Duplicate Source:  4547093008831923968
# GAIA Duplicate Source:  6633374850333268224
# GAIA Duplicate Source:  2606426776461192832
# GAIA Duplicate Source:  4279399551382652288
# GAIA Duplicate Source:  562612334632736512
# GAIA Duplicate Source:  262134601538910080
# GAIA Duplicate Source:  6045568787297147776
# GAIA Duplicate Source:  2262193668901700992
# GAIA Duplicate Source:  1046870550091143680
# GAIA Duplicate Source:  6215427871906453376
# GAIA Duplicate Source:  5070930550513808640
# GAIA Duplicate Source:  6112988710008010112
# GAIA Duplicate Source:  2588078538733228032
# GAIA Duplicate Source:  2786972152019617024
# GAIA Duplicate Source:  1001333691911451648
# GAIA Duplicate Source:  5324415053561705216
# GAIA Duplicate Source:  273601236505201152
# GAIA Duplicate Source:  5618772252096591872
# GAIA Duplicate Source:  5618772252096591872
# GAIA Duplicate Source:  4562514965086014976
# GAIA Duplicate Source:  5926616335140772224
# GAIA Duplicate Source:  5926616335140772224
# GAIA Duplicate Source:  4120265240629786496
# GAIA Duplicate Source:  2482588919263253376
# GAIA Duplicate Source:  6603541835695100032
# GAIA Duplicate Source:  3572250503403344384
# GAIA Duplicate Source:  1131774769268961280
# GAIA Duplicate Source:  1730081237068994688
# GAIA Duplicate Source:  2256427555047353216
# GAIA Duplicate Source:  1154689003908559744
# GAIA Duplicate Source:  1816395305030018816
# GAIA Duplicate Source:  4059090509602240256
# GAIA Duplicate Source:  6909623573397171328
# GAIA Duplicate Source:  6310318302364660096
# GAIA Duplicate Source:  813022465725850624
# GAIA Duplicate Source:  474275405793103360
# GAIA Duplicate Source:  5622173934916188672
# GAIA Duplicate Source:  5805395659215723264
# GAIA Duplicate Source:  6463844279180617600
# GAIA Duplicate Source:  2606985294007829632
# GAIA Duplicate Source:  3985231812438852224
# GAIA Duplicate Source:  6270070644869811456
# GAIA Duplicate Source:  2160682219940169344
# GAIA Duplicate Source:  3849452125093245696
# GAIA Duplicate Source:  213452727788037632
# GAIA Duplicate Source:  6671005360914434816
# GAIA Duplicate Source:  2148442215981444992
# GAIA Duplicate Source:  4809527089847867648
# GAIA Duplicate Source:  350516782152418688
# GAIA Duplicate Source:  3820166083130704000
# GAIA Duplicate Source:  2574136147178034688
# GAIA Duplicate Source:  3671423188052818432
# GAIA Duplicate Source:  452193638896601088
# GAIA Duplicate Source:  2270378845775996032
# GAIA Duplicate Source:  3807606671044567552
# GAIA Duplicate Source:  1153942710390897152
# GAIA Duplicate Source:  3503690902529389312
# GAIA Duplicate Source:  6437340104717699200
# GAIA Duplicate Source:  4392970203357519360
# GAIA Duplicate Source:  4055740572556348672
# GAIA Duplicate Source:  2106263850427894784
# GAIA Duplicate Source:  5762907678058275712
# GAIA Duplicate Source:  713532709410712448
# GAIA Duplicate Source:  4410089152725531776
# GAIA Duplicate Source:  3295279195038769792
# GAIA Duplicate Source:  893998198576957824
# GAIA Duplicate Source:  5770731356125650560
# GAIA Duplicate Source:  394874551551818240
# GAIA Duplicate Source:  5180432528430866688
# GAIA Duplicate Source:  1103742376721369728
# GAIA Duplicate Source:  5209815842812280704
# GAIA Duplicate Source:  4765263191255036672
# GAIA Duplicate Source:  2080849841744409984
# GAIA Duplicate Source:  5198244067046868096
# GAIA Duplicate Source:  6277664456286031872
# GAIA Duplicate Source:  3726647224709561088
# GAIA Duplicate Source:  1922740207107454336
# GAIA Duplicate Source:  6874355947663043712
# GAIA Duplicate Source:  6536607656604613760
# GAIA Duplicate Source:  2712006933841269248
# GAIA Duplicate Source:  5603612804247460352
# GAIA Duplicate Source:  6054493694983536384
# GAIA Duplicate Source:  4654214956391082368
# GAIA Duplicate Source:  6608821072056229504
# GAIA Duplicate Source:  6199824977274786304
# GAIA Duplicate Source:  561692558795745536
# GAIA Duplicate Source:  2018767395149954176
# GAIA Duplicate Source:  4597855089862907136
# GAIA Duplicate Source:  2664422922449456384
# GAIA Duplicate Source:  988336090081422336
# GAIA Duplicate Source:  2867701766063926912
# GAIA Duplicate Source:  221346121762092416
# GAIA Duplicate Source:  1003223580601456256
# GAIA Duplicate Source:  2019874912595884288
# GAIA Duplicate Source:  6777449115958649984
# GAIA Duplicate Source:  5103600030271425792
# GAIA Duplicate Source:  2503262795882038272
# GAIA Duplicate Source:  3311877560010615552
# GAIA Duplicate Source:  6124502623976215424
# GAIA Duplicate Source:  6255600041055885184
# GAIA Duplicate Source:  27293898690902656
# GAIA Duplicate Source:  3063507744541803648
# GAIA Duplicate Source:  6862053615138470784
# GAIA Duplicate Source:  1900081230964167040
# GAIA Duplicate Source:  5889011663079738624
# GAIA Duplicate Source:  6253190598762318080
# GAIA Duplicate Source:  2983367090771101696
# GAIA Duplicate Source:  4503302724871484416
# GAIA Duplicate Source:  2459733955172698624
# GAIA Duplicate Source:  4294093459140708736
# GAIA Duplicate Source:  890157982419475456
# GAIA Duplicate Source:  926855248146898176
# GAIA Duplicate Source:  6184589903641593088
# GAIA Duplicate Source:  367020417325472128
# GAIA Duplicate Source:  2410277681636721536
# GAIA Duplicate Source:  2700853178651742720
# GAIA Duplicate Source:  6857141684381064064
# GAIA Duplicate Source:  6845984321417779840
# GAIA Duplicate Source:  894252632440222848
# GAIA Duplicate Source:  3848464694931107200
# GAIA Duplicate Source:  4790128990314563200
# GAIA Duplicate Source:  4099794911103332608
# GAIA Duplicate Source:  1655648010720125824
# GAIA Duplicate Source:  1868985324150840192
# GAIA Duplicate Source:  6222957155734072832
# GAIA Duplicate Source:  3809463436946202880
# GAIA Duplicate Source:  5095980792648067840
# GAIA Duplicate Source:  1868985324144247808
# GAIA Duplicate Source:  342510928752813184
# GAIA Duplicate Source:  180064064343403520
# GAIA Duplicate Source:  2192107086902685312
# GAIA Duplicate Source:  3138183585003559808
# GAIA Duplicate Source:  5757482722046012800
# GAIA Duplicate Source:  2087586171530354688
# GAIA Duplicate Source:  5624788195608256000
# GAIA Duplicate Source:  1102505391780628864
# GAIA Duplicate Source:  3834061470564352128
# GAIA Duplicate Source:  5880168978258222080
# GAIA Duplicate Source:  3801364777893113728
# GAIA Duplicate Source:  6906039921406723328
# GAIA Duplicate Source:  4391052448920301696
# GAIA Duplicate Source:  3417003962688323584
# GAIA Duplicate Source:  540985902986721792
# GAIA Duplicate Source:  3124936875071121152
# GAIA Duplicate Source:  3004190982007742208
# GAIA Duplicate Source:  4998302138142243584
# GAIA Duplicate Source:  3858803230968437888
# GAIA Duplicate Source:  5173853016490550912
# GAIA Duplicate Source:  6097292116372402304
# GAIA Duplicate Source:  6531813957705938048
# GAIA Duplicate Source:  3129918830975042176
# GAIA Duplicate Source:  5045205139519618816
# GAIA Duplicate Source:  2285708821006287360
# GAIA Duplicate Source:  1809041702545976960
# GAIA Duplicate Source:  1036110420064078976
# GAIA Duplicate Source:  407988392375092224
# GAIA Duplicate Source:  5423654430461797632
# GAIA Duplicate Source:  5283902241962212096
# GAIA Duplicate Source:  6193365140302226432
# GAIA Duplicate Source:  1921895576018882944
# GAIA Duplicate Source:  5215824776937564800
# GAIA Duplicate Source:  606569503840673408
# GAIA Duplicate Source:  2921037357140599680
# GAIA Duplicate Source:  1379737421839743104
# GAIA Duplicate Source:  4850983419859237248
# GAIA Duplicate Source:  2674170917664197760
# GAIA Duplicate Source:  4509228611513985152
# GAIA Duplicate Source:  4500983614331140864
# GAIA Duplicate Source:  5958238083401392512
# GAIA Duplicate Source:  5337519548532811008
# GAIA Duplicate Source:  2984020922233440384
# GAIA Duplicate Source:  6687481611376626304
# GAIA Duplicate Source:  984840124141707648
# GAIA Duplicate Source:  5962853214739533568
# GAIA Duplicate Source:  2075037891998301312
# GAIA Duplicate Source:  2981630480874857088
# GAIA Duplicate Source:  2067478096721765376
# GAIA Duplicate Source:  596820855791669376
# GAIA Duplicate Source:  2690031338535173248
# GAIA Duplicate Source:  2929371655279264512
# GAIA Duplicate Source:  1214512606941823360
# GAIA Duplicate Source:  2305564386095417472
# GAIA Duplicate Source:  1703224806566756608
# GAIA Duplicate Source:  3782510696097914368
# GAIA Duplicate Source:  1134618759172982528
# GAIA Duplicate Source:  5987792852871028480
# GAIA Duplicate Source:  3458954385736082432
# GAIA Duplicate Source:  6348780593492807936
# GAIA Duplicate Source:  3870609786827670784
# GAIA Duplicate Source:  3679803150283421824
# GAIA Duplicate Source:  1631569908662484992
# GAIA Duplicate Source:  2731572605822353152
# GAIA Duplicate Source:  321511184375355264
# GAIA Duplicate Source:  3441630549249136256
# GAIA Duplicate Source:  5959478126358758016
# GAIA Duplicate Source:  3170303755624614528
# GAIA Duplicate Source:  2225421705102219776
# GAIA Duplicate Source:  6649211872221271296
# GAIA Duplicate Source:  5632435573858083968
# GAIA Duplicate Source:  3808918903812996992
# GAIA Duplicate Source:  2987751290308221440
# GAIA Duplicate Source:  3432846791370889472
# GAIA Duplicate Source:  3752121500375725568
# GAIA Duplicate Source:  3557719289010927744
# GAIA Duplicate Source:  2086063176129332224
# GAIA Duplicate Source:  2521415045662482688
# GAIA Duplicate Source:  313665344278621696
# GAIA Duplicate Source:  3975566486755346176
# GAIA Duplicate Source:  4357572148055781120
# GAIA Duplicate Source:  935710680437248640
# GAIA Duplicate Source:  5932115233312694016
# GAIA Duplicate Source:  327741670093720064
# GAIA Duplicate Source:  2206035322240382080
# GAIA Duplicate Source:  3135502975654364928
# GAIA Duplicate Source:  3892767591827413888
# GAIA Duplicate Source:  4057569232190158336
# GAIA Duplicate Source:  6164768629571883520
# GAIA Duplicate Source:  6463958147354408320
# GAIA Duplicate Source:  6668403985123804160
# GAIA Duplicate Source:  2034189420118197120
# GAIA Duplicate Source:  4805866953078834048
# Finished GAIA Duplicate Check. Found:  457
# Finished masking all GAIA duplicates. All sources involved
# 2MASS Duplicate Source:  b'06513367-4745000'
# 2MASS Duplicate Source:  b'07390663-4538576'
# 2MASS Duplicate Source:  b'21045848-1105139'
# 2MASS Duplicate Source:  b'18394121+0826384'
# 2MASS Duplicate Source:  b'02472995-0600508'
# 2MASS Duplicate Source:  b'21453071+2156249'
# 2MASS Duplicate Source:  b'13301834-4821531'
# 2MASS Duplicate Source:  b'06543186-0441583'
# 2MASS Duplicate Source:  b'03301382+7717357'
# 2MASS Duplicate Source:  b'13025615-3433226'
# 2MASS Duplicate Source:  b'15290917-3248329'
# 2MASS Duplicate Source:  b'17430747-8325108'
# 2MASS Duplicate Source:  b'21280133+4304426'
# 2MASS Duplicate Source:  b'01355504+3303195'
# 2MASS Duplicate Source:  b'05351451+3357454'
# 2MASS Duplicate Source:  b'10121865+1620542'
# 2MASS Duplicate Source:  b'08135422-5222547'
# 2MASS Duplicate Source:  b'20224375+1320260'
# 2MASS Duplicate Source:  b'05425760+5235097'
# 2MASS Duplicate Source:  b'19535484+1959019'
# 2MASS Duplicate Source:  b'05395413-1527271'
# 2MASS Duplicate Source:  b'06185319-3212053'
# 2MASS Duplicate Source:  b'17314135+1110544'
# 2MASS Duplicate Source:  b'18592211+2936102'
# 2MASS Duplicate Source:  b'07451457-0900204'
# 2MASS Duplicate Source:  b'05075506+0824082'
# Finished 2MASS Duplicate Check. Found:  26
# Masked  62  rows based on J-G color > 5 sigma from mean
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log10
#   del sys.path[0]
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
#
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log10
# /astromake/opt/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10

# %%
CreatePlots(colors,abs_color_mags,abs_color_std,color_mags,color_std)

# %%
print(colors)
print(avg_colors)
print(err_colors)
print(color_mags)
print(color_std)


PrintToFile(colors,avg_colors,err_colors,color_mags,color_std)
# Out:
# [0.5, 1, 1.5, 2, 2.5, 3]
# [ 0.2778096   0.83354451  1.27265005  1.7050845   2.16733439  2.67427228]
# [ 0.17433203  0.13610322  0.1349335   0.13856932  0.12832688  0.12657941]
# [[ 0.          0.          0.23989565  0.24253559  0.2778096 ]
#  [ 0.          0.          0.63657092  0.77753901  0.83354451]
#  [ 0.          0.          0.92735191  1.20062827  1.27265005]
#  [ 0.          0.          1.1977241   1.59370879  1.7050845 ]
#  [ 0.          0.          1.44233301  1.89368908  2.16733439]
#  [ 0.          0.          1.83875903  2.4126506   2.67427228]]
# [[ 0.          0.          0.12416791  0.16938361  0.17433203]
#  [ 0.          0.          0.11174483  0.14607786  0.13610322]
#  [ 0.          0.          0.10556694  0.14577656  0.1349335 ]
#  [ 0.          0.          0.15065002  0.20839007  0.13856932]
#  [ 0.          0.          0.32954202  0.53487965  0.12832688]
#  [ 0.          0.          0.29938619  0.48909329  0.12657941]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-b1502b90a2ef> in <module>()
#       6
#       7
# ----> 8 PrintToFile(colors,avg_colors,err_colors,color_mags,color_std)
#
# <ipython-input-66-b553247e998f> in PrintToFile(colors, avg_colors, err_colors, color_mags, color_std)
#      25         G_J_err = str(color_std[i,3])
#      26         G_K_err = str(color_std[i,4])
# ---> 27         row = color + "," + avg_col + "," + err_col + "," + G_B + "," + G_V + "," + G_H + ","                + G_J + "," + G_K + "," + G_B_err + "," + + G_V_err + "," + G_H_err + "," + G_J_err + ","                + G_K_err + "\n"
#      28         csv.write(row)
#      29     return
#
# TypeError: bad operand type for unary +: 'str'

# %%
G_K2 = Gmags - Kmags
J_K2 = Jmags - Kmags
x = G_K2
y  = J_K2
plt.scatter(x,y)
x2 = np.sort(x)
y2 = -0.215+0.468*x2-0.025*np.power(x2,2)
plt.plot(x2,y2,'k')
plt.xlabel('G-K')
plt.ylabel('J-K')
plt.title('J-K vs. G-K')
plt.show()

# %%
CreatePlots(colors,abs_color_mags,abs_color_std,color_mags,color_std)
